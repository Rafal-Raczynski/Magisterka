# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('gdp_data.csv')
data.head()
# Out:
#                 DATAFLOW        LAST UPDATE    freq  \
# 0  ESTAT:NAMA_10_PC(1.0)  05/12/25 23:00:00  Annual
# 1  ESTAT:NAMA_10_PC(1.0)  05/12/25 23:00:00  Annual
# 2  ESTAT:NAMA_10_PC(1.0)  05/12/25 23:00:00  Annual
# 3  ESTAT:NAMA_10_PC(1.0)  05/12/25 23:00:00  Annual
# 4  ESTAT:NAMA_10_PC(1.0)  05/12/25 23:00:00  Annual
#
#                               unit                                  na_item  \
# 0  Current prices, euro per capita  Gross domestic product at market prices
# 1  Current prices, euro per capita  Gross domestic product at market prices
# 2  Current prices, euro per capita  Gross domestic product at market prices
# 3  Current prices, euro per capita  Gross domestic product at market prices
# 4  Current prices, euro per capita  Gross domestic product at market prices
#
#        geo  TIME_PERIOD  OBS_VALUE OBS_FLAG  CONF_STATUS
# 0  Albania         2015     3590.0      NaN          NaN
# 1  Albania         2016     3770.0      NaN          NaN
# 2  Albania         2017     4100.0      NaN          NaN
# 3  Albania         2018     4540.0      NaN          NaN
# 4  Albania         2019     4880.0      NaN          NaN

# %%
print(data['unit'].unique())
# Out:
# ['Current prices, euro per capita'
#  'Current prices, units of national currency per capita'
#  'Current prices, purchasing power standard (PPS, EU27 from 2020) per capita']

# %%
polska_pps = data[(data['geo'] == 'Poland') & (data['unit'] == 'Current prices, purchasing power standard (PPS, EU27 from 2020) per capita')]
polska_pps
# Out:
#                    DATAFLOW        LAST UPDATE    freq  \
# 1130  ESTAT:NAMA_10_PC(1.0)  05/12/25 23:00:00  Annual
# 1131  ESTAT:NAMA_10_PC(1.0)  05/12/25 23:00:00  Annual
# 1132  ESTAT:NAMA_10_PC(1.0)  05/12/25 23:00:00  Annual
# 1133  ESTAT:NAMA_10_PC(1.0)  05/12/25 23:00:00  Annual
# 1134  ESTAT:NAMA_10_PC(1.0)  05/12/25 23:00:00  Annual
# 1135  ESTAT:NAMA_10_PC(1.0)  05/12/25 23:00:00  Annual
# 1136  ESTAT:NAMA_10_PC(1.0)  05/12/25 23:00:00  Annual
# 1137  ESTAT:NAMA_10_PC(1.0)  05/12/25 23:00:00  Annual
# 1138  ESTAT:NAMA_10_PC(1.0)  05/12/25 23:00:00  Annual
# 1139  ESTAT:NAMA_10_PC(1.0)  05/12/25 23:00:00  Annual
#
#                                                    unit  \
# 1130  Current prices, purchasing power standard (PPS...
# 1131  Current prices, purchasing power standard (PPS...
# 1132  Current prices, purchasing power standard (PPS...
# 1133  Current prices, purchasing power standard (PPS...
# 1134  Current prices, purchasing power standard (PPS...
# 1135  Current prices, purchasing power standard (PPS...
# 1136  Current prices, purchasing power standard (PPS...
# 1137  Current prices, purchasing power standard (PPS...
# 1138  Current prices, purchasing power standard (PPS...
# 1139  Current prices, purchasing power standard (PPS...
#
#                                       na_item     geo  TIME_PERIOD  OBS_VALUE  \
# 1130  Gross domestic product at market prices  Poland         2015    19407.6
# 1131  Gross domestic product at market prices  Poland         2016    19707.1
# 1132  Gross domestic product at market prices  Poland         2017    20729.9
# 1133  Gross domestic product at market prices  Poland         2018    21942.4
# 1134  Gross domestic product at market prices  Poland         2019    23345.3
# 1135  Gross domestic product at market prices  Poland         2020    23914.3
# 1136  Gross domestic product at market prices  Poland         2021    26195.3
# 1137  Gross domestic product at market prices  Poland         2022    28149.4
# 1138  Gross domestic product at market prices  Poland         2023    29572.1
# 1139  Gross domestic product at market prices  Poland         2024    31439.0
#
#      OBS_FLAG  CONF_STATUS
# 1130      NaN          NaN
# 1131      NaN          NaN
# 1132      NaN          NaN
# 1133      NaN          NaN
# 1134      NaN          NaN
# 1135        b          NaN
# 1136      NaN          NaN
# 1137        b          NaN
# 1138      NaN          NaN
# 1139      NaN          NaN

# %%
wyniki = polska_pps[['TIME_PERIOD', 'OBS_VALUE']].sort_values('TIME_PERIOD')
print(wyniki)
# Out:
#       TIME_PERIOD  OBS_VALUE
# 1130         2015    19407.6
# 1131         2016    19707.1
# 1132         2017    20729.9
# 1133         2018    21942.4
# 1134         2019    23345.3
# 1135         2020    23914.3
# 1136         2021    26195.3
# 1137         2022    28149.4
# 1138         2023    29572.1
# 1139         2024    31439.0
